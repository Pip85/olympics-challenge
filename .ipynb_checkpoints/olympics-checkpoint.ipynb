# %%
#Project 1
#Andrew Miller, Valerie Pippenger, Damiso Hutchinson, Caroline Larry, Diana Kennen

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Save csv file names
file_one = "summer_olympics.csv"
file_two = "gdp.csv"

# %%
#Import csv files
olympicsI_df = pd.read_csv(file_one, encoding="ISO-8859-1")
gdp_df = pd.read_csv(file_two, encoding="ISO-8859-1")

# %%
#View olympics file
olympicsI_df.head()
# Out:
#      City  Year     Sport Discipline                               Event  \
# 0  Athens  2004  Aquatics     Diving                      3m springboard
# 1  Athens  2004  Aquatics     Diving                      3m springboard
# 2  Athens  2004  Aquatics     Diving                      3m springboard
# 3  Athens  2004  Aquatics     Diving  synchronized diving 3m springboard
# 4  Athens  2004  Aquatics     Diving  synchronized diving 3m springboard
#
#                Athlete Gender Country_Code    Country Event_gender   Medal
# 0  DESPATIE, Alexandre    Men          CAN     Canada            M  Silver
# 1       SAUTIN, Dmitry    Men          RUS     Russia            M  Bronze
# 2    PAKHALINA, Ioulia  Women          RUS     Russia            W  Bronze
# 3      NEWBERY, Robert    Men          AUS  Australia            M  Bronze
# 4        BIMIS, Thomas    Men          GRE     Greece            M    Gold

# %%
#Drop NaN
olympicsI_df.dropna()
# Out:
#          City  Year      Sport       Discipline  \
# 0      Athens  2004   Aquatics           Diving
# 1      Athens  2004   Aquatics           Diving
# 2      Athens  2004   Aquatics           Diving
# 3      Athens  2004   Aquatics           Diving
# 4      Athens  2004   Aquatics           Diving
# ...       ...   ...        ...              ...
# 15311  Sydney  2000  Wrestling  Wrestling Gre-R
# 15312  Sydney  2000  Wrestling  Wrestling Gre-R
# 15313  Sydney  2000  Wrestling  Wrestling Gre-R
# 15314  Sydney  2000  Wrestling  Wrestling Gre-R
# 15315  Sydney  2000  Wrestling  Wrestling Gre-R
#
#                                     Event               Athlete Gender  \
# 0                          3m springboard   DESPATIE, Alexandre    Men
# 1                          3m springboard        SAUTIN, Dmitry    Men
# 2                          3m springboard     PAKHALINA, Ioulia  Women
# 3      synchronized diving 3m springboard       NEWBERY, Robert    Men
# 4      synchronized diving 3m springboard         BIMIS, Thomas    Men
# ...                                   ...                   ...    ...
# 15311                           69 - 76kg  LINDLAND, Matt James    Men
# 15312                          97 - 130kg    KARELIN, Aleksandr    Men
# 15313                           76 - 85kg      YERLIKAYA, Hamza    Men
# 15314                           54 - 58kg           KIM, In-Sub    Men
# 15315                           58 - 63kg      MAREN, Juan Luis    Men
#
#       Country_Code        Country Event_gender   Medal
# 0              CAN         Canada            M  Silver
# 1              RUS         Russia            M  Bronze
# 2              RUS         Russia            W  Bronze
# 3              AUS      Australia            M  Bronze
# 4              GRE         Greece            M    Gold
# ...            ...            ...          ...     ...
# 15311          USA  United States            M  Silver
# 15312          RUS         Russia            M  Silver
# 15313          TUR         Turkey            M    Gold
# 15314          KOR   Korea, South            M  Silver
# 15315          CUB           Cuba            M  Silver
#
# [15316 rows x 11 columns]

# %%
#Checking for file types and number of data points
olympicsI_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15316 entries, 0 to 15315
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  int64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.3+ MB

# %%
#Setting year to be a string
olympicsI_df = olympicsI_df.fillna(0)
olympicsI_df["Year"] = olympicsI_df["Year"].astype(int)
olympicsI_df["Year"] = olympicsI_df["Year"].astype(str)

# %%
#Viewing gdp df
gdp_df.head()
# Out:
#         Entity Code  Year  GDP (constant 2010 US$)
# 0  Afghanistan  AFG  2002             8.013233e+09
# 1  Afghanistan  AFG  2003             8.689884e+09
# 2  Afghanistan  AFG  2004             8.781610e+09
# 3  Afghanistan  AFG  2005             9.762979e+09
# 4  Afghanistan  AFG  2006             1.030523e+10

# %%
#Fix South Korea
olympicsI_df["Country"].replace({"Korea, South": "South Korea", "Korea, North": "North Korea"}, inplace = True)

# %%
#Concatenating the country and year for the purpose of merging the two files
olympicsI_df["combo"] = olympicsI_df["Country"] + olympicsI_df["Year"]
olympicsI_df.head()
# Out:
#      City  Year     Sport Discipline                               Event  \
# 0  Athens  2004  Aquatics     Diving                      3m springboard
# 1  Athens  2004  Aquatics     Diving                      3m springboard
# 2  Athens  2004  Aquatics     Diving                      3m springboard
# 3  Athens  2004  Aquatics     Diving  synchronized diving 3m springboard
# 4  Athens  2004  Aquatics     Diving  synchronized diving 3m springboard
#
#                Athlete Gender Country_Code    Country Event_gender   Medal  \
# 0  DESPATIE, Alexandre    Men          CAN     Canada            M  Silver
# 1       SAUTIN, Dmitry    Men          RUS     Russia            M  Bronze
# 2    PAKHALINA, Ioulia  Women          RUS     Russia            W  Bronze
# 3      NEWBERY, Robert    Men          AUS  Australia            M  Bronze
# 4        BIMIS, Thomas    Men          GRE     Greece            M    Gold
#
#            combo
# 0     Canada2004
# 1     Russia2004
# 2     Russia2004
# 3  Australia2004
# 4     Greece2004

# %%
#Counting the number if datapoints from each city
olympicsI_df.City.value_counts()
# Out:
# Beijing        2042
# Sydney         2015
# Athens         1998
# Atlanta        1859
# Barcelona      1705
# Seoul          1546
# Los Angeles    1459
# Moscow         1387
# Montreal       1305
# Name: City, dtype: int64

# %%
#Creating a function for assigning host countries
def country_getter(city):
    if city == 'Beijing':
        return('China')
    elif city == 'Sydney':
        return('Australia')
    elif city ==  "Athens":
        return("Greece")
    elif city == "Atlanta":
        return("United States")
    elif city == "Barcelona":
        return("Spain")
    elif city == "Montreal":
        return("Canada")
    elif city == "Seoul":
        return("South Korea")
    elif city == "Los Angeles":
        return("United States")
    elif city == "Moscow":
        return("Russia")
    else:
        return('country not found')

# %%
#Applying host country function
olympicsI_df['host country'] = olympicsI_df.City.apply(country_getter)

# %%
#Double Checking host country counts
olympicsI_df["host country"].value_counts()
# Out:
# United States    3318
# China            2042
# Australia        2015
# Greece           1998
# Spain            1705
# South Korea      1546
# Russia           1387
# Canada           1305
# Name: host country, dtype: int64

# %%
#Concatenating gdp country and year for merge purposes
gdp_df["combo"] = gdp_df["Entity"] + gdp_df["Year"].map(str)

# %%
#Checking for new combo column
gdp_df.head()
# Out:
#         Entity Code  Year  GDP (constant 2010 US$)            combo
# 0  Afghanistan  AFG  2002             8.013233e+09  Afghanistan2002
# 1  Afghanistan  AFG  2003             8.689884e+09  Afghanistan2003
# 2  Afghanistan  AFG  2004             8.781610e+09  Afghanistan2004
# 3  Afghanistan  AFG  2005             9.762979e+09  Afghanistan2005
# 4  Afghanistan  AFG  2006             1.030523e+10  Afghanistan2006

# %%
korea_list = olympicsI_df[olympicsI_df["Country"]== "South Korea"]
korea_list
# Out:
#          City  Year      Sport       Discipline  \
# 333    Athens  2004    Archery          Archery
# 336    Athens  2004    Archery          Archery
# 337    Athens  2004    Archery          Archery
# 343    Athens  2004    Archery          Archery
# 346    Athens  2004    Archery          Archery
# ...       ...   ...        ...              ...
# 15111  Sydney  2000  Taekwondo        Taekwondo
# 15286  Sydney  2000  Wrestling  Wrestling Free.
# 15289  Sydney  2000  Wrestling  Wrestling Free.
# 15307  Sydney  2000  Wrestling  Wrestling Gre-R
# 15314  Sydney  2000  Wrestling  Wrestling Gre-R
#
#                                        Event          Athlete Gender  \
# 333          team (FITA Olympic round - 70m)  PARK, Sung-Hyun  Women
# 336          team (FITA Olympic round - 70m)    IM, Dong Hyun    Men
# 337    individual (FITA Olympic round - 70m)  PARK, Sung-Hyun  Women
# 343          team (FITA Olympic round - 70m)    JANG, Yong-Ho    Men
# 346          team (FITA Olympic round - 70m)   PARK, Kyung Mo    Men
# ...                                      ...              ...    ...
# 15111                             49 - 57 kg    JUNG, Jae-Eun  Women
# 15286                              69 - 76kg    MOON, Eui Jae    Men
# 15289                              58 - 63kg   JANG, Jae-Sung    Men
# 15307                              48 - 54kg     SIM, Kwon-Ho    Men
# 15314                              54 - 58kg      KIM, In-Sub    Men
#
#       Country_Code      Country Event_gender   Medal            combo  \
# 333            KOR  South Korea            W    Gold  South Korea2004
# 336            KOR  South Korea            M    Gold  South Korea2004
# 337            KOR  South Korea            W    Gold  South Korea2004
# 343            KOR  South Korea            M    Gold  South Korea2004
# 346            KOR  South Korea            M    Gold  South Korea2004
# ...            ...          ...          ...     ...              ...
# 15111          KOR  South Korea            W    Gold  South Korea2000
# 15286          KOR  South Korea            M  Silver  South Korea2000
# 15289          KOR  South Korea            M  Bronze  South Korea2000
# 15307          KOR  South Korea            M    Gold  South Korea2000
# 15314          KOR  South Korea            M  Silver  South Korea2000
#
#       host country
# 333         Greece
# 336         Greece
# 337         Greece
# 343         Greece
# 346         Greece
# ...            ...
# 15111    Australia
# 15286    Australia
# 15289    Australia
# 15307    Australia
# 15314    Australia
#
# [454 rows x 13 columns]

# %%
#Merging two dataframes
olympics_df = pd.merge(olympicsI_df, gdp_df, on="combo", how = "left")

# %%
olympics_df.drop('Code', inplace=True, axis=1)
olympics_df.drop('Country_Code', inplace=True, axis=1)
olympics_df.drop('Entity', inplace=True, axis=1)
olympics_df.rename(columns = {"Year_y": "GDP Year", "Year_x": "Olympics Year"}, inplace = True)

# %%
olympics_df.head()
# Out:
#      City Olympics Year     Sport Discipline  \
# 0  Athens          2004  Aquatics     Diving
# 1  Athens          2004  Aquatics     Diving
# 2  Athens          2004  Aquatics     Diving
# 3  Athens          2004  Aquatics     Diving
# 4  Athens          2004  Aquatics     Diving
#
#                                 Event              Athlete Gender    Country  \
# 0                      3m springboard  DESPATIE, Alexandre    Men     Canada
# 1                      3m springboard       SAUTIN, Dmitry    Men     Russia
# 2                      3m springboard    PAKHALINA, Ioulia  Women     Russia
# 3  synchronized diving 3m springboard      NEWBERY, Robert    Men  Australia
# 4  synchronized diving 3m springboard        BIMIS, Thomas    Men     Greece
#
#   Event_gender   Medal          combo host country  GDP Year  \
# 0            M  Silver     Canada2004       Greece    2004.0
# 1            M  Bronze     Russia2004       Greece    2004.0
# 2            W  Bronze     Russia2004       Greece    2004.0
# 3            M  Bronze  Australia2004       Greece    2004.0
# 4            M    Gold     Greece2004       Greece    2004.0
#
#    GDP (constant 2010 US$)
# 0             1.480000e+12
# 1             1.200000e+12
# 2             1.200000e+12
# 3             9.640000e+11
# 4             3.030000e+11

# %%
olympics_df.sort_values(by = "Country").head()
# Out:
#               City Olympics Year      Sport Discipline  \
# 7363       Beijing          2008  Taekwondo  Taekwondo
# 8082   Los Angeles          1984     Boxing     Boxing
# 4475     Barcelona          1992     Boxing     Boxing
# 2371       Atlanta          1996  Athletics  Athletics
# 13780       Sydney          2000  Athletics  Athletics
#
#                                Event               Athlete Gender  \
# 7363                         - 58 kg      NIKPAI, Rohullah    Men
# 8082   75 - 81kg (light-heavyweight)      MOUSSA, Mustapha    Men
# 4475       54 - 57kg (featherweight)       SOLTANI, Hocine    Men
# 2371                           1500m   MORCELI, Nourredine    Men
# 13780                          1500m  MERAH-BENIDA, Nouria  Women
#
#            Country Event_gender   Medal            combo   host country  \
# 7363   Afghanistan            M  Bronze  Afghanistan2008          China
# 8082       Algeria            M  Bronze      Algeria1984  United States
# 4475       Algeria            M  Bronze      Algeria1992          Spain
# 2371       Algeria            M    Gold      Algeria1996  United States
# 13780      Algeria            W    Gold      Algeria2000      Australia
#
#        GDP Year  GDP (constant 2010 US$)
# 7363     2008.0             1.214448e+10
# 8082     1984.0             8.540465e+10
# 4475     1992.0             9.252182e+10
# 2371     1996.0             9.699483e+10
# 13780    2000.0             1.100000e+11

# %%
#Differences in data point count are due to changes in names of countries.
olympics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15316 entries, 0 to 15315
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   City                     15316 non-null  object
#  1   Olympics Year            15316 non-null  object
#  2   Sport                    15316 non-null  object
#  3   Discipline               15316 non-null  object
#  4   Event                    15316 non-null  object
#  5   Athlete                  15316 non-null  object
#  6   Gender                   15316 non-null  object
#  7   Country                  15316 non-null  object
#  8   Event_gender             15316 non-null  object
#  9   Medal                    15316 non-null  object
#  10  combo                    15316 non-null  object
#  11  host country             15316 non-null  object
#  12  GDP Year                 11909 non-null  float64
#  13  GDP (constant 2010 US$)  11909 non-null  float64
# dtypes: float64(2), object(12)
# memory usage: 1.8+ MB

# %%
olympics_df.to_csv("olympics.csv", header = True)

# %%
 #### Randomly select 5 sports

# %%
sport = olympics_df["Sport"]
sport.sample(5)
# Out:
# 11641    Volleyball
# 14509    Gymnastics
# 10753    Basketball
# 1521         Rowing
# 2628         Boxing
# Name: Sport, dtype: object

# %%
### Which countries tend to win at what sports?

# %%
## Top 10 countries in basketball

bball = olympics_df[olympics_df.Sport == "Basketball"].groupby(["Country"]).Medal.size()
top_10_bball = bball.sort_values(ascending = False)[:10]
bball_bar = top_10_bball.plot.bar(alpha=0.75, width=0.5)

# Generating title and labels for X & Y axis
bball_bar.set_title("Medals Earned in Basketball (Top 10 Countries)")
bball_bar.set_xlabel("Country")
bball_bar.set_ylabel("Number of Medals")

# Formatting the bar chart using a for loop
for b in bball_bar.patches:
     bball_bar.annotate(f'{int(b.get_height())}', 
                        (b.get_x() + b.get_width() / 2.0, 
                         b.get_height()),
                         ha = 'center', 
                         va = 'center',
                         xytext = (0, 6),
                         textcoords = 'offset points')

# Rotating x-ticks 45 degrees
plt.xticks(rotation=45)

# Setting axis length
plt.ylim(0, max(bball) + 25)

# Showing the bar plot
plt.show()

# %%
## Top 10 countries in volleyball

vball = olympics_df[olympics_df.Sport == "Volleyball"].groupby(["Country"]).Medal.size()
top_10_vball = vball.sort_values(ascending = False)[:10]
vball_bar = top_10_vball.plot.bar(alpha=0.75, width=0.5)

# Generating title and labels for X & Y axis
vball_bar.set_title("Medals Earned in Volleyball (Top 10 Countries)")
vball_bar.set_xlabel("Country")
vball_bar.set_ylabel("Number of Medals")

for v in vball_bar.patches:
     vball_bar.annotate(f'{int(v.get_height())}', 
                        (v.get_x() + v.get_width() / 2.0, 
                         v.get_height()),
                         ha = 'center', 
                         va = 'center',
                         xytext = (0, 6),
                         textcoords = 'offset points')

# Rotating x-ticks 45 degrees
plt.xticks(rotation=45)

# Setting axis length
plt.ylim(0, max(vball) + 25)

# Showing the bar plot
plt.show()

# %%
## Top 10 countries in gymnastics

gymnast = olympics_df[olympics_df.Sport == "Gymnastics"].groupby(["Country"]).Medal.size()
top_10_gymnastics = gymnast.sort_values(ascending = False)[:10]
gymnast_bar = top_10_gymnastics.plot.bar(alpha=0.75, width=0.5)

# Generating title and labels for X & Y axis
gymnast_bar.set_title("Medals Earned in Gymnastics (Top 10 Countries)")
gymnast_bar.set_xlabel("Country")
gymnast_bar.set_ylabel("Number of Medals")

for g in gymnast_bar.patches:
     gymnast_bar.annotate(f'{int(g.get_height())}', 
                        (g.get_x() + g.get_width() / 2.0, 
                         g.get_height()),
                         ha = 'center', 
                         va = 'center',
                         xytext = (0, 6),
                         textcoords = 'offset points')

# Rotating x-ticks 45 degrees
plt.xticks(rotation=45)

# Setting axis length
plt.ylim(0, max(gymnast) + 25)

# Showing the bar plot
plt.show()

# %%
## Top 10 countries in boxing

boxing = olympics_df[olympics_df.Sport == "Boxing"].groupby(["Country"]).Medal.size()
top_10_boxing = boxing.sort_values(ascending = False)[:10]
boxing_bar = top_10_boxing.plot.bar(alpha=0.75, width=0.5)

# Generating title and labels for X & Y axis
boxing_bar.set_title("Medals Earned in Boxing (Top 10 Countries)")
boxing_bar.set_xlabel("Country")
boxing_bar.set_ylabel("Number of Medals")

for box in boxing_bar.patches:
     boxing_bar.annotate(f'{int(box.get_height())}', 
                        (box.get_x() + box.get_width() / 2.0, 
                         box.get_height()),
                         ha = 'center', 
                         va = 'center',
                         xytext = (0, 6),
                         textcoords = 'offset points')

# Rotating x-ticks 45 degrees
plt.xticks(rotation=45)

# Setting axis length
plt.ylim(0, max(boxing) + 25)

# Showing the bar plot
plt.show()

# %%
## Top 10 countries in rowing

rowing = olympics_df[olympics_df.Sport == "Rowing"].groupby(["Country"]).Medal.size()
top_10_row = rowing.sort_values(ascending = False)[:10]
row_bar = top_10_row.plot.bar(alpha=0.75, width=0.5)

# Generating title and labels for X & Y axis
row_bar.set_title("Medals Earned in Rowing (Top 10 Countries)")
row_bar.set_xlabel("Country")
row_bar.set_ylabel("Number of Medals")

for row in row_bar.patches:
     row_bar.annotate(f'{int(row.get_height())}', 
                        (row.get_x() + row.get_width() / 2.0, 
                         row.get_height()),
                         ha = 'center', 
                         va = 'center',
                         xytext = (0, 6),
                         textcoords = 'offset points')

# Rotating x-ticks 45 degrees
plt.xticks(rotation=45)

# Setting axis length
plt.ylim(0, max(rowing) + 25)

# Showing the bar plot
plt.show()
